# %%
print("Hello Jupiter Notebook !!")
# Out:
# Hello Jupiter Notebook !!

# %% [markdown]
# # MY First Notebook
# This is a Simple Math Equation:
#     $a^2 + b^2 = c^2$

# %% [markdown]
# # Question 4: Float Precision
#
# **Objective:** Handle floating-point arithmetic with functions, validation, and formatted output.
#
# **Task:** Write a Python program to calculate the net salary after tax deduction and display the result with 2 decimal places.
#
# **Instructions:**
# - Use salary = 75000.5 and tax_rate = 0.18.
# - Use a function.
# - Validate salary and tax rate.
# - Use variables.
# - Format the output to 2 decimal places.

# %%
def calculate_net_salary(salary, tax_rate):
    if salary < 0:
        print("Invalid salary")
        return
    if tax_rate < 0 or tax_rate > 1:
        print("Invalid tax rate")
        return
    tax = salary * tax_rate
    net_salary = salary - tax
    print(f"\nSalary        : {salary:.2f}")
    print(f"Tax Amount    : {tax:.2f}")
    print(f"Net Salary    : {net_salary:.2f}")
salary = float(input("Enter salary: "))
tax_rate = float(input("Enter tax rate: "))
calculate_net_salary(salary, tax_rate)

# %% [markdown]
# # Question 5: Multiple Assignment
#
# **Objective:** Use multiple assignment with basic validation, function, and formatted output.
#
# **Task:** Unpack (x, y) coordinates and display them.

# %%
def display_coordinates(x, y):
    if not isinstance(x, (int, float)) or not isinstance(y, (int, float)):
        print("Invalid coordinates")
        return

    print(f"X Coordinate : {x:.2f}")
    print(f"Y Coordinate : {y:.2f}")

x = float(input("Enter X Coordinate: "))
y = float(input("Enter Y Coordinate: "))

display_coordinates(x, y)
# Out:
# Enter X Coordinate:  50
# Enter Y Coordinate:  80
# X Coordinate : 50.00
# Y Coordinate : 80.00

# %% [markdown]
# # Question 6: Modulo Operator
#
# **Objective:** Use the modulo operator with function, validation, and clean output.
#
# **Task:** Write a Python program to check whether a number is even or odd using the modulo (%) operator.
#
# **Instructions:**
# - Use a function.
# - Validate the number.
# - Compute the remainder.
# - Print "Even" or "Odd".
# - Use variable `number = 17`.

# %%
def check_even_odd(number):
    if not isinstance(number, int):
        print("Invalid number")
        return

    remainder = number % 2

    if remainder == 0:
        print("Even")
    else:
        print("Odd")

number = int(input("Enter a number: "))

check_even_odd(number)
# Out:
# Enter a number:  46
# Even

# %% [markdown]
# # Question 7: Floor Division
#
# **Objective:** Perform integer division with function, validation, and formatted output.
#
# **Task:** Write a Python program to split a total bill equally among people using the floor division (//) operator.
#
# **Instructions:**
# - Use a function.
# - Validate the total bill and number of people.
# - Use floor division (//).
# - Print the individual share.
# - Get input from the user.

# %%
def split_bill(total_bill, people):
    if total_bill <= 0:
        print("Invalid bill amount")
        return

    if people <= 0:
        print("Invalid number of people")
        return

    share = total_bill // people

    print(f"Total Bill      : {total_bill}")
    print(f"No. of People   : {people}")
    print(f"Individual Share: {share}")

total_bill = int(input("Enter Total Bill: "))
people = int(input("Enter Number of People: "))

split_bill(total_bill, people)
# Out:
# Enter Total Bill:  1698
# Enter Number of People:  5
# Total Bill      : 1698
# No. of People   : 5
# Individual Share: 339

# %% [markdown]
# # Question 8: Min/Max Functions
#
# **Objective:** Use built-in min() and max() functions with validation, function, and structured output.
#
# **Task:** Write a Python program to find the highest and lowest salary in a list.
#
# **Instructions:**
# - Use a function.
# - Validate the salary list.
# - Compute minimum and maximum salaries.
# - Print the results.
# - Get salary values from the user.

# %%
def find_salary_range(salaries):
    if len(salaries) == 0:
        print("Salary list is empty")
        return
    lowest_salary = min(salaries)
    highest_salary = max(salaries)
    print(f"Salary List   : {salaries}")
    print(f"Lowest Salary : {lowest_salary}")
    print(f"Highest Salary: {highest_salary}")
salaries = list(map(int, input("Enter salaries separated by space: ").split()))
find_salary_range(salaries)
# Out:
# Enter salaries separated by space:   50000 75000 62000 95000
# Salary List   : [50000, 75000, 62000, 95000]
# Lowest Salary : 50000
# Highest Salary: 95000

# %% [markdown]
# # Question 9: Basic Input
#
# **Objective:** Read and validate user input using a function and formatted output.
#
# **Task:** Write a Python program to get the user's name and display a greeting message.
#
# **Instructions:**
# - Use a function.
# - Validate empty input.
# - Use input().
# - Print a greeting message.

# %%
def greet_user(name):
    if name.strip() == "":
        print("Name cannot be empty")
        return

    print(f"Hello, {name}! Welcome.")

name = input("Enter your name: ")

greet_user(name)
# Out:
# Enter your name:  Vaishu
# Hello, Vaishu! Welcome.

# %% [markdown]
# # Question 10: Numeric Input
#
# **Objective:** Convert user input to a number with validation, function, and formatted output.
#
# **Task:** Write a Python program to ask the user for their age, validate the input, convert it to an integer, and display the age they will be next year.
#
# **Instructions:**
# - Use a function.
# - Validate numeric input.
# - Convert using int().
# - Print "Next year you'll be <age+1>".

# %%
def next_year_age(age):
    if age < 0:
        print("Invalid age")
        return

    print(f"Next year you'll be {age + 1}")

age_input = input("Enter your age: ")

if age_input.isdigit():
    age = int(age_input)
    next_year_age(age)
else:
    print("Please enter a valid numeric age")
# Out:
# Enter your age:  21
# Next year you'll be 22

# %% [markdown]
# # Question 11: Float Input
#
# **Objective:** Handle decimal input with validation, function, and formatted output.
#
# **Task:** Write a Python program to convert weight from kilograms to pounds.
#
# **Instructions:**
# - Use a function.
# - Validate decimal input.
# - Convert kg to lbs using the formula: lbs = kg * 2.20462.
# - Print the weight in pounds.

# %%
def convert_weight(kg):
    if kg <= 0:
        print("Invalid weight")
        return
    lbs = kg * 2.20462
    print(f"Weight in Kilograms : {kg:.2f} kg")
    print(f"Weight in Pounds    : {lbs:.2f} lbs")
try:
    kg = float(input("Enter weight in kilograms: "))
    convert_weight(kg)
except ValueError:
    print("Please enter a valid decimal number")
# Out:
# Enter weight in kilograms:  65.5
# Weight in Kilograms : 65.50 kg
# Weight in Pounds    : 144.40 lbs

# %% [markdown]
# # Question 12: Simple If
#
# **Objective:** Use a basic conditional statement with function, validation, and user interaction.
#
# **Task:** Write a Python program to check whether a student passes or fails based on marks.
#
# **Instructions:**
# - Use a function.
# - Validate marks.
# - Get marks from the user.
# - Print "Pass" or "Fail".

# %%
def check_result(marks):
    if marks < 0 or marks > 100:
        print("Invalid marks")
        return

    if marks >= 50:
        print("Pass")
    else:
        print("Fail")

marks = int(input("Enter marks: "))

check_result(marks)
# Out:
# Enter marks:  85
# Pass

# %% [markdown]
# # Question 13: If-Else
#
# **Objective:** Use a two-way decision with functions, validation, and formatted output.
#
# **Task:** Write a Python program to check whether a number is even or odd.
#
# **Instructions:**
# - Use a function.
# - Validate the input.
# - Get the number from the user.
# - Print "Even" or "Odd".

# %%
def check_even_odd(num):
    if num < 0:
        print("Invalid input")
        return

    if num % 2 == 0:
        print("Even")
    else:
        print("Odd")

num = int(input("Enter a number: "))

check_even_odd(num)
# Out:
# Enter a number:  85
# Odd

# %% [markdown]
# # Question 14: If-Elif-Else
#
# **Objective:** Use a multi-way decision with functions, validation, and structured output.
#
# **Task:** Write a Python program to assign a grade based on the student's score.
#
# **Instructions:**
# - Use a function.
# - Validate the score.
# - Get the score from the user.
# - Print grade A/B/C.
# - Add slight enhancements over the basic version.

# %%
def assign_grade(score):
    if score < 0 or score > 100:
        print("Invalid score")
        return

    if score >= 90:
        grade = "A"
        remark = "Excellent"
    elif score >= 75:
        grade = "B"
        remark = "Good"
    else:
        grade = "C"
        remark = "Needs Improvement"

    print(f"Score  : {score}")
    print(f"Grade  : {grade}")
    print(f"Remark : {remark}")

score = int(input("Enter your score: "))

assign_grade(score)
# Out:
# Enter your score:  75
# Score  : 75
# Grade  : B
# Remark : Good

# %% [markdown]
# # Question 15: Nested If
#
# **Objective:** Use nested conditions with a function, basic validation, and formatted output.
#
# **Task:** Write a Python program to validate a username and password using nested if statements.
#
# **Instructions:**
# - Use a function.
# - Validate blank inputs.
# - Use nested if statements for username and password validation.
# - Get username and password from the user.
# - Valid credentials:
#   - Username = "admin"
#   - Password = "pass123"

# %%
def validate_login(user, pwd):
    if user.strip() == "" or pwd.strip() == "":
        print("Username or Password cannot be empty")
        return

    if user == "admin":
        if pwd == "pass123":
            print("Login Successful")
        else:
            print("Incorrect Password")
    else:
        print("Invalid Username")

user = input("Enter Username: ")
pwd = input("Enter Password: ")

validate_login(user, pwd)
# Out:
# Enter Username:  admin
# Enter Password:  pass125
# Incorrect Password

# %% [markdown]
# # Question 17: While Loop
#
# **Objective:** Use a condition-based loop with validation, function, and formatted output.
#
# **Task:** Write a Python program to perform a countdown from 5 to 1 using a while loop.
#
# **Instructions:**
# - Use a function.
# - Validate count value.
# - Use while count > 0:
# - Print count each step.
# - Decrease count using count -= 1.

# %%
def countdown(count):
    if count <= 0:
        print("Invalid count")
        return

    print("Countdown:")

    while count > 0:
        print(count)
        count -= 1

count = int(input("Enter starting count: "))

countdown(count)
# Out:
# Enter starting count:  8
# Countdown:
# 8
# 7
# 6
# 5
# 4
# 3
# 2
# 1

# %% [markdown]
# # Question 18: Break Statement
#
# **Objective:** Use a break statement to exit a loop early with function, validation, and clean output.
#
# **Task:** Find and print the first even number in a given range.
#
# **Instructions:**
# - Use a function
# - Validate the range size
# - Loop with for i in range(...)
# - Use modulo % to check even
# - Break once the first even is found

# %%
def first_even(limit):
    if limit <= 0:
        print("Invalid range")
        return

    for i in range(limit):
        if i % 2 == 0 and i != 0:
            print("First Even Number:", i)
            break

limit = int(input("Enter range: "))
first_even(limit)
# Out:
# Enter range:  10
# First Even Number: 2

# %% [markdown]
# # Question 19: Continue Statement
#
# **Objective:** Use continue to skip even numbers, with a function, validation, and formatted output.
#
# **Task:** Sum only the odd numbers in a given range.
#
# **Instructions:**
# - Use a function
# - Validate the range
# - Loop with range(10)
# - Skip even numbers using continue
# - Accumulate only odd numbers

# %%
def sum_odd_numbers(limit):
    if limit <= 0:
        print("Invalid range")
        return

    total = 0

    for i in range(limit):
        if i % 2 == 0:
            continue
        total += i

    print("Sum of Odd Numbers:", total)

sum_odd_numbers(10)
# Out:
# Sum of Odd Numbers: 25

# %% [markdown]
# # Question 20: Pass Statement
#
# **Objective:** Use pass as a placeholder inside a function, with simple structure and formatted output.
#
# **Task:** Define an empty function using pass and print confirmation.
#
# **Instructions:**
# - Use a function
# - Add placeholder logic with pass
# - Call the function
# - Print "Function defined"

# %%
def sample_function():
    pass

sample_function()

print("Function defined")
# Out:
# Function defined

# %% [markdown]
# # Question 21: Consistent Indentation
#
# **Objective:** Demonstrate clean, consistent indentation using a nested if inside a function.
#
# **Task:** Print "Nested" when both conditions are True.
#
# **Instructions:**
# - Use a function
# - Apply exactly 4 spaces per indentation level
# - Use nested if-statements
# - Print "Nested"
# - Print confirmation message

# %%
def check_conditions(a, b):
    if a:
        if b:
            print("Nested")

    print("Conditions Checked")

check_conditions(True, True)
# Out:
# Nested
# Conditions Checked

# %% [markdown]
# # Question 22: Comment Usage
#
# **Objective:** Show proper documentation using meaningful comments and a function.
#
# **Task:** Add explanatory comments and print the total salary.
#
# **Instructions:**
# - Use clear comments
# - Use a function
# - Define base and bonus
# - Calculate total
# - Print result

# %%
def total_salary():
    # Base salary
    base = 50000

    # Bonus amount
    bonus = 10000

    # Calculate total salary
    total = base + bonus

    print("Total Salary:", total)

total_salary()
# Out:
# Total Salary: 60000

# %% [markdown]
# # Question 23: Import Standard Module
#
# **Objective:** Use the math module inside a function with validation and formatted output.
#
# **Task:** Calculate the area of a circle using math.pi and a given radius.
#
# **Instructions:**
# - Import math
# - Use a function
# - Validate radius
# - Use formula: area = math.pi × radius²
# - Print area with 2 decimals

# %%
import math

def area_circle(radius):
    if radius <= 0:
        print("Invalid radius")
        return

    area = math.pi * radius ** 2
    print(f"Area = {area:.2f}")

radius = float(input("Enter radius: "))
area_circle(radius)
# Out:
# Enter radius:  6
# Area = 113.10

# %% [markdown]
# # Question 24: All Import
#
# **Objective:** Use from module import * along with simple utility usage inside a function.
#
# **Task:** Import everything from a standard module and use a few functions.
#
# **Instructions:**
# - Use from math import *
# - Use a function
# - Validate some input
# - Demonstrate usage (sqrt, pow, pi)
# - Print results

# %%
from math import *

def math_demo(num):
    if num < 0:
        print("Invalid number")
        return

    print("Square Root:", sqrt(num))
    print("Power:", pow(num, 2))
    print("Pi:", pi)

num = int(input("Enter number: "))
math_demo(num)
# Out:
# Enter number:  9
# Square Root: 3.0
# Power: 81.0
# Pi: 3.141592653589793

# %% [markdown]
# # Question 25: Parameters
#
# **Objective:** Pass arguments into a function with validation and structured output.
#
# **Task:** Create a function that adds two numbers and prints the result.
#
# **Instructions:**
# - Use a function with parameters
# - Validate inputs
# - Return the sum
# - Print the result of add(5, 3)

# %%
def add(a, b):
    if not isinstance(a, (int, float)) or not isinstance(b, (int, float)):
        print("Invalid Input")
        return

    return a + b

result = add(5, 3)
print("Sum =", result)
# Out:
# Sum = 8

# %% [markdown]
# # Question 26: Multiple Parameters
#
# **Objective:** Handle multiple arguments in a function with validation and formatted output.
#
# **Task:** Calculate the area of a rectangle using length and width.
#
# **Instructions:**
# - Use a function that accepts two arguments
# - Validate the numbers
# - Calculate and return area
# - Print area(5, 3)

# %%
def area(length, width):
    if length <= 0 or width <= 0:
        print("Invalid Input")
        return

    return length * width

result = area(5, 3)
print("Area =", result)
# Out:
# Area = 15

# %% [markdown]
# # Question 27: Len Function
#
# **Objective:** Use len() inside a function with basic validation and structured output.
#
# **Task:** Get the length of a given string.
#
# **Instructions:**
# - Use a function
# - Validate the string
# - Use len(text)
# - Print the length

# %%
def string_length(text):
    if text.strip() == "":
        print("Empty String")
        return

    print("Length =", len(text))

text = input("Enter text: ")
string_length(text)
# Out:
# Enter text:   python program
# Length = 15

# %% [markdown]
# # Question 28: Write to File
#
# **Objective:** Create and write to a text file using a function and clean structure.
#
# **Task:** Save a greeting message into a text file.
#
# **Instructions:**
# - Use a function
# - Open a file in write mode
# - Write "Hello World" into the file
# - Print confirmation message

# %%
def write_file():
    file = open("greeting.txt", "w")
    file.write("Hello World")
    file.close()

    print("File written successfully")

write_file()
# Out:
# File written successfully

# %% [markdown]
# # Question 29: Read from File
#
# **Objective:** Read text from a file using a function with basic error handling.
#
# **Task:** Open a text file and display its contents.
#
# **Instructions:**
# - Use a function
# - Open file in read mode
# - Read full content using read()
# - Print file content
# - Handle missing file gracefully

# %%
def read_file():
    try:
        file = open("greeting.txt", "r")
        content = file.read()
        file.close()

        print(content)

    except FileNotFoundError:
        print("File not found")

read_file()
# Out:
# Hello World

# %% [markdown]
# # Question 30: Basic Try-Except
#
# **Objective:** Catch simple runtime errors using try-except with a function and clear output.
#
# **Task:** Safely divide two numbers and handle division-by-zero errors.
#
# **Instructions:**
# - Use a function
# - Use try-except
# - Handle ZeroDivisionError
# - Print result or error message

# %%
def divide(a, b):
    try:
        result = a / b
        print("Result =", result)

    except ZeroDivisionError:
        print("Cannot divide by zero")

a = float(input("Enter first number: "))
b = float(input("Enter second number: "))

divide(a, b)
# Out:
# Enter first number:  10
# Enter second number:  3
# Result = 3.3333333333333335

# %% [markdown]
# # Question 31: Create List
#
# **Objective:** Initialize a list with basic validation, a function, and clean output.
#
# **Task:** Create a shopping cart list and display the items.
#
# **Instructions:**
# - Use a function
# - Validate list items
# - Initialize list with values [100, 250, 75]
# - Print the cart contents

# %%
def display_cart(cart):
    if len(cart) == 0:
        print("Cart is empty")
        return

    print("Cart Contents:", cart)

cart = [100, 250, 75]

display_cart(cart)
# Out:
# Cart Contents: [100, 250, 75]

# %% [markdown]
# # Question 32: Append to List
#
# **Objective:** Add a single item to a list using a function with validation.
#
# **Task:** Add a new expense to an existing expenses list.
#
# **Instructions:**
# - Use a function
# - Validate the expense amount
# - Use .append()
# - Print the updated expenses list

# %%
def add_expense(expenses, amount):
    if amount <= 0:
        print("Invalid expense")
        return

    expenses.append(amount)

    print("Updated Expenses:", expenses)

expenses = [1000, 2000, 1500]

amount = int(input("Enter expense: "))

add_expense(expenses, amount)
# Out:
# Enter expense:  5000
# Updated Expenses: [1000, 2000, 1500, 5000]

# %% [markdown]
# # Question 33: Update Dictionary
#
# **Objective:** Perform bulk dictionary updates using a function with basic validation.
#
# **Task:** Merge employee details from two dictionaries.
#
# **Instructions:**
# - Use a function
# - Validate dictionary inputs
# - Use .update()
# - Print the updated employee data

# %%
def merge_data(emp1, emp2):
    if not isinstance(emp1, dict) or not isinstance(emp2, dict):
        print("Invalid Input")
        return

    emp1.update(emp2)

    print("Updated Employee Data:", emp1)

emp1 = {"Name": "John"}
emp2 = {"Salary": 50000}

merge_data(emp1, emp2)
# Out:
# Updated Employee Data: {'Name': 'John', 'Salary': 50000}

# %% [markdown]
# # Question 34: Nested Dictionary
#
# **Objective:** Work with nested dictionaries using a function and basic validation.
#
# **Task:** Store department-wise employee data and retrieve a specific employee’s salary.
#
# **Instructions:**
# - Use a nested dictionary
# - Use a function to fetch data
# - Validate department and employee name
# - Print the employee salary

# %%
def get_salary(data, dept, emp):
    if dept not in data:
        print("Department not found")
        return

    if emp not in data[dept]:
        print("Employee not found")
        return

    print("Salary:", data[dept][emp])

employees = {
    "IT": {"Raj": 60000, "Priya": 70000},
    "HR": {"Anu": 50000}
}

get_salary(employees, "IT", "Raj")
# Out:
# Salary: 60000

# %% [markdown]
# # Question 35: Create Tuple
#
# **Objective:** Use an immutable tuple with a function and basic validation.
#
# **Task:** Store fixed coordinates and display them.
#
# **Instructions:**
# - Use a tuple
# - Use a function
# - Validate coordinate values
# - Print coordinates in a readable format

# %%
def display_coordinates(coords):
    if len(coords) != 2:
        print("Invalid Coordinates")
        return

    print(f"X = {coords[0]}, Y = {coords[1]}")

coordinates = (10, 20)

display_coordinates(coordinates)
# Out:
# X = 10, Y = 20

# %% [markdown]
# # Question 36: Set Intersection
#
# **Objective:** Find common elements between two sets using a function and basic validation.
#
# **Task:** Identify common skills between two skill sets.
#
# **Instructions:**
# - Use sets
# - Use a function
# - Validate inputs
# - Find intersection using &
# - Print common skills

# %%
def common_skills(set1, set2):
    if len(set1) == 0 or len(set2) == 0:
        print("Invalid Input")
        return

    common = set1 & set2

    print("Common Skills:", common)

skills1 = {"Python", "Java", "SQL"}
skills2 = {"Python", "C++", "SQL"}

common_skills(skills1, skills2)
# Out:
# Common Skills: {'Python', 'SQL'}

# %% [markdown]
# # Question 37: Multiple Instances
#
# **Objective:** Create multiple objects from a class and access their attributes.
#
# **Task:** Create an employee roster using multiple instances of a class.
#
# **Instructions:**
# - Define a class with __init__
# - Create multiple objects (instances)
# - Add a method to display employee info
# - Print employee names

# %%
class Employee:
    def __init__(self, name):
        self.name = name

    def display(self):
        print("Employee Name:", self.name)

emp1 = Employee("Raj")
emp2 = Employee("Priya")
emp3 = Employee("Arun")

emp1.display()
emp2.display()
emp3.display()
# Out:
# Employee Name: Raj
# Employee Name: Priya
# Employee Name: Arun

# %% [markdown]
# # Question 38: Method Chaining
#
# **Objective:** Demonstrate method chaining by returning self from methods.
#
# **Task:** Create an employee object, set salary, apply raise, and display final salary.
#
# **Instructions:**
# - Create a class
# - Methods should return self
# - Use method chaining
# - Add basic validation
# - Print final salary

# %%
class Employee:
    def __init__(self):
        self.salary = 0

    def set_salary(self, salary):
        if salary > 0:
            self.salary = salary
        return self

    def apply_raise(self, amount):
        if amount > 0:
            self.salary += amount
        return self

    def display(self):
        print("Final Salary:", self.salary)
        return self

Employee().set_salary(50000).apply_raise(5000).display()
# Out:
# Final Salary: 55000

# %% [markdown]
# # Question 39: Polymorphism
#
# **Objective:** Demonstrate polymorphism using method overriding.
#
# **Task:** Show different behaviors of the same method (work()) for different employee types.
#
# **Instructions:**
# - Create a base class with a common method
# - Override the method in child classes
# - Store objects in a list
# - Call the same method for all objects
# - Observe different outputs

# %%
class Employee:
    def work(self):
        print("Employee is working")

class Developer(Employee):
    def work(self):
        print("Developer writes code")

class Manager(Employee):
    def work(self):
        print("Manager manages team")

employees = [Developer(), Manager()]

for emp in employees:
    emp.work()
# Out:
# Developer writes code
# Manager manages team

# %% [markdown]
# # Question 40: Class Methods
#
# **Objective:** Use a class method as a factory to create objects from a formatted string.
#
# **Task:** Create an Employee object from a string like "Shubh,75000".
#
# **Instructions:**
# - Use @classmethod
# - Parse string input
# - Convert salary to integer
# - Return a new object using cls
# - Print employee details

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    @classmethod
    def from_string(cls, data):
        name, salary = data.split(",")
        return cls(name, int(salary))

    def display(self):
        print("Name:", self.name)
        print("Salary:", self.salary)

emp = Employee.from_string("Shubh,75000")

emp.display()
# Out:
# Name: Shubh
# Salary: 75000

# %% [markdown]
# # Question 41: Employee Management System
#
# **Objective:** Use classes, dictionaries, lists, and JSON file I/O together.
#
# **Task:** Create an employee management system that can save and load employee data.
#
# **Instructions:**
# - Create Employee class with __init__ and __str__
# - Store employees in a dictionary
# - Save data to emps.json
# - Load data back from file
# - Print all employees

# %%
import json

class Employee:
    def __init__(self, emp_id, name, salary):
        self.emp_id = emp_id
        self.name = name
        self.salary = salary

    def __str__(self):
        return f"{self.emp_id} - {self.name} - {self.salary}"

employees = {
    "E101": {"name": "Raj", "salary": 50000},
    "E102": {"name": "Priya", "salary": 60000}
}

with open("emps.json", "w") as file:
    json.dump(employees, file)

with open("emps.json", "r") as file:
    data = json.load(file)

for emp_id, details in data.items():
    emp = Employee(emp_id, details["name"], details["salary"])
    print(emp)
# Out:
# E101 - Raj - 50000
# E102 - Priya - 60000

# %% [markdown]
# # Question 47: Complete Calculator Program
#
# **Objective:** Combine input, functions, and error handling.
#
# **Task:** Build a robust calculator that supports +, -, *, /.
#
# **Instructions:**
# - Create function calculate(a, b, op) handling +, -, *, /
# - Use input() for numbers and operation
# - Handle ZeroDivisionError and ValueError
# - Print formatted result

# %%
def calculate(a, b, op):
    try:
        if op == "+":
            return a + b
        elif op == "-":
            return a - b
        elif op == "*":
            return a * b
        elif op == "/":
            return a / b
        else:
            return "Invalid Operator"

    except ZeroDivisionError:
        return "Cannot divide by zero"

try:
    a = float(input("Enter First Number: "))
    b = float(input("Enter Second Number: "))
    op = input("Enter Operator (+,-,*,/): ")

    result = calculate(a, b, op)

    print("Result =", result)

except ValueError:
    print("Invalid Input")
# Out:
# Enter First Number:  10
# Enter Second Number:  5
# Enter Operator (+,-,*,/):  *
# Result = 50.0

# %% [markdown]
# # Question 48: Shopping Cart System
#
# **Objective:** Use classes, lists, control flow, and the math module to build a simple shopping cart system.
#
# **Task:** Perform complete cart operations and print a receipt with GST.
#
# **Instructions:**
# - Create CartItem class with price and quantity
# - Create ShoppingCart class
# - Add item
# - Remove item
# - Calculate total
# - Apply 18% GST
# - Print final receipt

# %%
class CartItem:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

class ShoppingCart:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)

    def calculate_total(self):
        total = sum(item.price * item.quantity for item in self.items)
        gst = total * 0.18

        print("Subtotal =", total)
        print("GST =", gst)
        print("Final Total =", total + gst)

cart = ShoppingCart()

cart.add_item(CartItem("Pen", 10, 5))
cart.add_item(CartItem("Book", 100, 2))

cart.calculate_total()
# Out:
# Subtotal = 250
# GST = 45.0
# Final Total = 295.0

# %% [markdown]
# # Question 49: Temperature Converter GUI
#
# **Objective:** Use classes, user input, modules, and formatted output.
#
# **Task:** Convert temperatures between Celsius, Fahrenheit, and Kelvin.
#
# **Instructions:**
# - Converter class
# - Convert C ↔ F ↔ K
# - Use input() menu
# - Format output to 2 decimals
# - Use tabulate module for table display

# %%
from tabulate import tabulate

class Converter:

    def c_to_f(self, c):
        return (c * 9/5) + 32

    def c_to_k(self, c):
        return c + 273.15

converter = Converter()

celsius = float(input("Enter Celsius: "))

fahrenheit = converter.c_to_f(celsius)
kelvin = converter.c_to_k(celsius)

table = [
    ["Celsius", f"{celsius:.2f}"],
    ["Fahrenheit", f"{fahrenheit:.2f}"],
    ["Kelvin", f"{kelvin:.2f}"]
]

print(tabulate(table, headers=["Scale", "Value"]))
# Out:
# Enter Celsius:  25
# Scale         Value
# ----------  -------
# Celsius       25
# Fahrenheit    77
# Kelvin       298.15

# %% [markdown]
# # Question 50: Backup Utility
#
# **Objective:** Use file operations, modules, sets, and error handling to build a smart backup tool.
#
# **Task:** Copy files to a backup folder while skipping duplicates and logging operations.
#
# **Instructions:**
# - Use shutil module
# - Copy files but skip duplicates using sets
# - Handle FileNotFoundError, PermissionError
# - Log operations to backup.log

# %%
import shutil

copied_files = set()

def backup_file(source, destination):
    try:
        if source in copied_files:
            print("Duplicate file skipped")
            return

        shutil.copy(source, destination)

        copied_files.add(source)

        with open("backup.log", "a") as log:
            log.write(f"Copied: {source}\n")

        print("Backup Successful")

    except FileNotFoundError:
        print("Source file not found")

    except PermissionError:
        print("Permission denied")

source = input("Enter Source File: ")
destination = input("Enter Backup Folder: ")

backup_file(source, destination)
# Out:
# Enter Source File:  sample.txt
# Enter Backup Folder:  backup
# Source file not found

# %% [markdown]
# # Question 51: URL Shortener
#
# **Objective:** Use dictionaries, hashing, classes, and modules to build a simple URL shortening service.
#
# **Task:** Create a basic URL shortener that can shorten URLs and retrieve the original URL.
#
# **Instructions:**
# - Import hashlib
# - URLShortener class with dictionary storage
# - Generate 6-character hash from URL
# - Lookup (redirect simulation) functionality

# %%
import hashlib

class URLShortener:
    def __init__(self):
        self.urls = {}

    def shorten(self, url):
        short = hashlib.md5(url.encode()).hexdigest()[:6]
        self.urls[short] = url
        return short

    def lookup(self, short):
        return self.urls.get(short, "URL Not Found")

shortener = URLShortener()

url = "https://www.google.com"

short_code = shortener.shorten(url)

print("Short URL:", short_code)
print("Original URL:", shortener.lookup(short_code))
# Out:
# Short URL: 8ffdef
# Original URL: https://www.google.com

# %% [markdown]
# # Question 52: Gradebook System
#
# **Objective:** Use dictionaries, functions, control flow, and file I/O for student grade management.
#
# **Task:** Manage student grades, calculate GPA, save/load data, and compute class average.
#
# **Instructions:**
# - Dictionary: student → list of grades
# - Functions: add grade, calculate GPA, save/load
# - Handle invalid grade inputs
# - Print class average

# %%
import json

students = {}

def add_grade(name, grade):
    if grade < 0 or grade > 100:
        print("Invalid Grade")
        return

    students.setdefault(name, []).append(grade)

def calculate_gpa(name):
    return sum(students[name]) / len(students[name])

add_grade("Raj", 80)
add_grade("Raj", 90)
add_grade("Priya", 85)

class_average = sum(sum(v) for v in students.values()) / sum(len(v) for v in students.values())

print("Raj GPA:", calculate_gpa("Raj"))
print("Class Average:", class_average)
# Out:
# Raj GPA: 85.0
# Class Average: 85.0

# %% [markdown]
# # Question 53: Task Scheduler
#
# **Objective:** Use classes, the datetime module, lists, and sorting to manage tasks.
#
# **Task:** Create a task scheduler that prioritizes tasks by due date and identifies overdue tasks.
#
# **Instructions:**
# - Task class with due_date and priority
# - Store tasks in a list
# - Sort tasks by due date using datetime
# - Filter overdue tasks
# - Print sorted task schedule

# %%
from datetime import datetime

class Task:
    def __init__(self, name, due_date, priority):
        self.name = name
        self.due_date = datetime.strptime(due_date, "%Y-%m-%d")
        self.priority = priority

tasks = [
    Task("Report", "2026-06-10", 1),
    Task("Meeting", "2026-06-05", 2)
]

tasks.sort(key=lambda x: x.due_date)

print("Task Schedule")

for task in tasks:
    print(task.name, task.due_date.date(), task.priority)
# Out:
# Task Schedule
# Meeting 2026-06-05 2
# Report 2026-06-10 1

# %% [markdown]
# # Question 54: Inventory Manager
#
# **Objective:** Use classes, inheritance, dictionaries, and sets to manage warehouse inventory.
#
# **Task:** Track products, stock levels, and generate low-stock alerts.
#
# **Instructions:**
# - Product base class
# - Perishable and Electronics inherit from Product
# - Track stock levels using a dictionary
# - Use sets for low-stock alerts
# - Print inventory summary

# %%
class Product:
    def __init__(self, name):
        self.name = name

class Perishable(Product):
    pass

class Electronics(Product):
    pass

inventory = {
    "Milk": 5,
    "Laptop": 20,
    "Bread": 3
}

low_stock = {item for item, qty in inventory.items() if qty < 10}

print("Inventory:", inventory)
print("Low Stock Alerts:", low_stock)
# Out:
# Inventory: {'Milk': 5, 'Laptop': 20, 'Bread': 3}
# Low Stock Alerts: {'Milk', 'Bread'}

# %% [markdown]
# # Question 55: Budget Planner
#
# **Objective:** Use classes, control flow, external modules, and visualization to track a monthly budget.
#
# **Task:** Create a monthly budget planner that tracks spending, alerts overspending, and visualizes data.
#
# **Instructions:**
# - Category class with limit and spent
# - Input expenses using a loop
# - Use matplotlib for pie chart visualization

# %%
import matplotlib.pyplot as plt

class Category:
    def __init__(self, name, limit, spent):
        self.name = name
        self.limit = limit
        self.spent = spent

food = Category("Food", 5000, 3500)
travel = Category("Travel", 3000, 2500)
bills = Category("Bills", 4000, 4500)

categories = [food, travel, bills]

for c in categories:
    if c.spent > c.limit:
        print(c.name, "Overspent")

labels = [c.name for c in categories]
amounts = [c.spent for c in categories]

plt.pie(amounts, labels=labels)
plt.title("Monthly Budget")
plt.show()
# Out:
# Bills Overspent
